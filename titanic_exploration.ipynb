# %% [markdown]
# <a href="https://colab.research.google.com/github/KehindeG/Data_402_Python/blob/main/titanic_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Exploration
#
# #### Here I am exploring the dataset

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.shape
# Out:
# (891, 15)

# %%
missing_data = df.isna().sum()
print(missing_data)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
duplicate_data = df.duplicated().sum()
print(duplicate_data)
# Out:
# 107

# %%
duplicate_data = df[df.duplicated()]
print(duplicate_data)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female   NaN      0      0   7.7500        Q   Third
# 76          0       3    male   NaN      0      0   7.8958        S   Third
# 77          0       3    male   NaN      0      0   8.0500        S   Third
# 87          0       3    male   NaN      0      0   8.0500        S   Third
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Data Cleaning
#
# #### After exploring the dataset, we can now begin to clean it. I am creating a new dataset to work on, which will afford me the freedom of mistakes.
#
# #### Our new datset is called 'df_new'
#
# #### I am creating a copy of the dataset using .copy() rather than placing the dataset in a variable. Placing the dataset in a new variable means that any changes made will still affect the dataset.

# %%
# Creating a direct copy of the dataset
df_new = df.copy()
df_new
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Here I am dropping the column 'deck' as it contains too many missing values and it does not seem to be of much value as a column

# %%
# Using 'inplace=True' to directly alter the dataset
df_new.drop(columns=['deck'], inplace=True)

# %%
df_new.head(50)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
df_new.shape
# Out:
# (891, 14)

# %%
# Getting a new view of the amount of missing values in each row
missing_data = df_new.isna().sum()
print(missing_data)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# Returning all the rows in the dataset & whether the value in column 'age' is missing or not and placing them in a variable to use

# %%
missing_ages = df_new['age'].isna()
# print(missing_ages) # Just checking

# %% [markdown]
# Trying to view only the rows where the 'age' value is missing
# using the boolean value- returning the rows where '.isna()' returns as 'True'

# %%
missing_ages_rows = df_new[missing_ages]
# print(missing_ages_rows) - prints a not-so-pretty view of all the 'missing_ages_rows'
missing_ages_rows.head(60)
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked   class  \
# 5           0       3    male  NaN      0      0    8.4583        Q   Third
# 17          1       2    male  NaN      0      0   13.0000        S  Second
# 19          1       3  female  NaN      0      0    7.2250        C   Third
# 26          0       3    male  NaN      0      0    7.2250        C   Third
# 28          1       3  female  NaN      0      0    7.8792        Q   Third
# 29          0       3    male  NaN      0      0    7.8958        S   Third
# 31          1       1  female  NaN      1      0  146.5208        C   First
# 32          1       3  female  NaN      0      0    7.7500        Q   Third
# 36          1       3    male  NaN      0      0    7.2292        C   Third
# 42          0       3    male  NaN      0      0    7.8958        C   Third
# 45          0       3    male  NaN      0      0    8.0500        S   Third
# ...

# %%
# df_new.loc[0:50, 'age']

# %%
# df_new.iloc[50, 3]

# %%
# Using 'subset' to specify that I want to drop the rows where the value in the
# column 'age' is missing
df_new.dropna(subset=['age'], inplace=True)

# %%
df_new.head(60)
# Out:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.00      1      0    7.2500        S   Third
# 1          1       1  female  38.00      1      0   71.2833        C   First
# 2          1       3  female  26.00      0      0    7.9250        S   Third
# 3          1       1  female  35.00      1      0   53.1000        S   First
# 4          0       3    male  35.00      0      0    8.0500        S   Third
# 6          0       1    male  54.00      0      0   51.8625        S   First
# 7          0       3    male   2.00      3      1   21.0750        S   Third
# 8          1       3  female  27.00      0      2   11.1333        S   Third
# 9          1       2  female  14.00      1      0   30.0708        C  Second
# 10         1       3  female   4.00      1      1   16.7000        S   Third
# 11         1       1  female  58.00      0      0   26.5500        S   First
# ...

# %%
df_new.shape
# Out:
# (714, 14)

# %%
df_new.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
missing_embark_town = df_new['embark_town'].isna()
print(missing_embark_town)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 885    False
# 886    False
# 887    False
# 889    False
# 890    False
# Name: embark_town, Length: 714, dtype: bool

# %%
# Viewing the rows where value for column 'embark_town' is missing
missing_embark_town_rows = df_new[missing_embark_town]
missing_embark_town_rows.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male embark_town alive  alone
# 61   woman       False         NaN   yes   True
# 829  woman       False         NaN   yes   True

# %%
# Dropping those two rows & getting updated row/coloumn numbers
df_new.dropna(subset=['embark_town'], inplace=True)
df_new.shape
# Out:
# (712, 14)

# %%
df_new.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# The result of the above shows that the two rows above with missing 'embark_town' values were also the two rows with missing 'embarked' values

# %%
df_new.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %%
df_new.head(60)
# Out:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.00      1      0    7.2500        S   Third
# 1          1       1  female  38.00      1      0   71.2833        C   First
# 2          1       3  female  26.00      0      0    7.9250        S   Third
# 3          1       1  female  35.00      1      0   53.1000        S   First
# 4          0       3    male  35.00      0      0    8.0500        S   Third
# 6          0       1    male  54.00      0      0   51.8625        S   First
# 7          0       3    male   2.00      3      1   21.0750        S   Third
# 8          1       3  female  27.00      0      2   11.1333        S   Third
# 9          1       2  female  14.00      1      0   30.0708        C  Second
# 10         1       3  female   4.00      1      1   16.7000        S   Third
# 11         1       1  female  58.00      0      0   26.5500        S   First
# ...

# %%
#duplicated_data = df_new.duplicated().sum()
#print(duplicated_data)

# %%
#duplicated_data = df_new[duplicated_data]
#print(duplicated_data)

# %%
df_new.drop_duplicates(inplace=True)
df_new
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# In this section, I will be replacing values in the dataset.

# %%
# Replacing '1' and '0' with Yes and No
df_new['survived'] = df_new['survived'].replace(1, "Yes")
df_new['survived'] = df_new['survived'].replace(0, "No")
df_new
# (When using inplace, returns 'None"- why?)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         No       3    male  22.0      1      0   7.2500        S   Third
# 1        Yes       1  female  38.0      1      0  71.2833        C   First
# 2        Yes       3  female  26.0      0      0   7.9250        S   Third
# 3        Yes       1  female  35.0      1      0  53.1000        S   First
# 4         No       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 883       No       2    male  28.0      0      0  10.5000        S  Second
# 885       No       3  female  39.0      0      5  29.1250        Q   Third
# 887      Yes       1  female  19.0      0      0  30.0000        S   First
# 889      Yes       1    male  26.0      0      0  30.0000        C   First
# 890       No       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
# Replacing values '1, 2, 3' with their corresponding class titles
df_new['pclass'] = df_new['pclass'].replace(1, "Upper")
df_new['pclass'] = df_new['pclass'].replace(2, "Middle")
df_new['pclass'] = df_new['pclass'].replace(3, "Lower")
df_new.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0        No   Lower    male  22.0      1      0   7.2500        S   Third
# 1       Yes   Upper  female  38.0      1      0  71.2833        C   First
# 2       Yes   Lower  female  26.0      0      0   7.9250        S   Third
# 3       Yes   Upper  female  35.0      1      0  53.1000        S   First
# 4        No   Lower    male  35.0      0      0   8.0500        S   Third
# 6        No   Upper    male  54.0      0      0  51.8625        S   First
# 7        No   Lower    male   2.0      3      1  21.0750        S   Third
# 8       Yes   Lower  female  27.0      0      2  11.1333        S   Third
# 9       Yes  Middle  female  14.0      1      0  30.0708        C  Second
# 10      Yes   Lower  female   4.0      1      1  16.7000        S   Third
#
#       who  adult_male  embark_town alive  alone
# 0     man        True  Southampton    no  False
# 1   woman       False    Cherbourg   yes  False
# ...

# %% [markdown]
# In this section, I will be reformatting the numerical data values.

# %%
# Casting values for 'age' as int to remove decimals
df_new['age']= df_new['age'].astype(int)
df_new.head(10)
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0        No   Lower    male   22      1      0   7.2500        S   Third
# 1       Yes   Upper  female   38      1      0  71.2833        C   First
# 2       Yes   Lower  female   26      0      0   7.9250        S   Third
# 3       Yes   Upper  female   35      1      0  53.1000        S   First
# 4        No   Lower    male   35      0      0   8.0500        S   Third
# 6        No   Upper    male   54      0      0  51.8625        S   First
# 7        No   Lower    male    2      3      1  21.0750        S   Third
# 8       Yes   Lower  female   27      0      2  11.1333        S   Third
# 9       Yes  Middle  female   14      1      0  30.0708        C  Second
# 10      Yes   Lower  female    4      1      1  16.7000        S   Third
#
#       who  adult_male  embark_town alive  alone
# 0     man        True  Southampton    no  False
# 1   woman       False    Cherbourg   yes  False
# ...

# %%
# Removing the extra decimals from the 'fare' values
df_new['fare'] = df_new['fare'].round()
df_new.head(10)
# Out:
#    survived  pclass     sex  age  sibsp  parch  fare embarked   class    who  \
# 0        No   Lower    male   22      1      0   7.0        S   Third    man
# 1       Yes   Upper  female   38      1      0  71.0        C   First  woman
# 2       Yes   Lower  female   26      0      0   8.0        S   Third  woman
# 3       Yes   Upper  female   35      1      0  53.0        S   First  woman
# 4        No   Lower    male   35      0      0   8.0        S   Third    man
# 6        No   Upper    male   54      0      0  52.0        S   First    man
# 7        No   Lower    male    2      3      1  21.0        S   Third  child
# 8       Yes   Lower  female   27      0      2  11.0        S   Third  woman
# 9       Yes  Middle  female   14      1      0  30.0        C  Second  child
# 10      Yes   Lower  female    4      1      1  17.0        S   Third  child
#
#     adult_male  embark_town alive  alone
# 0         True  Southampton    no  False
# ...

# %% [markdown]
# Now that we're done with the main cleaning, I'll be renaming the columns.

# %%
# Renaming the neccessary columns
df_new.rename(columns={'pclass': 'social_class', 'embarked': 'embarked_code', 'class': 'ticket_class', 'who': 'demographic'}, inplace=True)
df_new.head(50)
# Out:
#    survived social_class     sex  age  sibsp  parch   fare embarked_code  \
# 0        No        Lower    male   22      1      0    7.0             S
# 1       Yes        Upper  female   38      1      0   71.0             C
# 2       Yes        Lower  female   26      0      0    8.0             S
# 3       Yes        Upper  female   35      1      0   53.0             S
# 4        No        Lower    male   35      0      0    8.0             S
# 6        No        Upper    male   54      0      0   52.0             S
# 7        No        Lower    male    2      3      1   21.0             S
# 8       Yes        Lower  female   27      0      2   11.0             S
# 9       Yes       Middle  female   14      1      0   30.0             C
# 10      Yes        Lower  female    4      1      1   17.0             S
# 11      Yes        Upper  female   58      0      0   27.0             S
# 12       No        Lower    male   20      0      0    8.0             S
# ...

# %% [markdown]
# ## Exploring the data
#
# #### Now I will explore possible insights within this cleaned dataset

# %%
df_new.describe().round()
# Out:
#          age  sibsp  parch   fare
# count  674.0  674.0  674.0  674.0
# mean    30.0    1.0    0.0   36.0
# std     15.0    1.0    1.0   54.0
# min      0.0    0.0    0.0    0.0
# 25%     20.0    0.0    0.0    8.0
# 50%     28.0    0.0    0.0   16.0
# 75%     39.0    1.0    1.0   35.0
# max     80.0    5.0    6.0  512.0

# %% [markdown]
# **Exploring:** The average fare and age for each class

# %%
# Finding the average fare for each class
average_fare_class = df_new.groupby('social_class')['fare'].mean().round(2)
print(average_fare_class)
# Out:
# social_class
# Lower     13.38
# Middle    22.15
# Upper     88.51
# Name: fare, dtype: float64

# %%
# Finding the average age for each class
average_age_class = df_new.groupby('social_class')['age'].mean().astype(int)
print(average_age_class)
# Out:
# social_class
# Lower     25
# Middle    29
# Upper     38
# Name: age, dtype: int64

# %% [markdown]
# **Exploring:** The percentages of the fares

# %%
# Add a new column showing the fare as a percentage of total
df_new['fare parcentage'] = ((df_new['fare'] / df_new['fare'].sum()) * 100).round(2)
df_new.head(20)
# Out:
#    survived social_class     sex  age  sibsp  parch  fare embarked_code  \
# 0        No        Lower    male   22      1      0   7.0             S
# 1       Yes        Upper  female   38      1      0  71.0             C
# 2       Yes        Lower  female   26      0      0   8.0             S
# 3       Yes        Upper  female   35      1      0  53.0             S
# 4        No        Lower    male   35      0      0   8.0             S
# 6        No        Upper    male   54      0      0  52.0             S
# 7        No        Lower    male    2      3      1  21.0             S
# 8       Yes        Lower  female   27      0      2  11.0             S
# 9       Yes       Middle  female   14      1      0  30.0             C
# 10      Yes        Lower  female    4      1      1  17.0             S
# 11      Yes        Upper  female   58      0      0  27.0             S
# 12       No        Lower    male   20      0      0   8.0             S
# ...

# %% [markdown]
# **Exploring:** How many survivors were female compared to male?

# %%
# Returning total survivors as an integer
# total_survivors = 0

# for value in df_new['survived']:
#   if value == "Yes":
#     total_survivors += 1
# print("Total survivors: ", total_survivors)

# Accessing where 'survived' is 'Yes'
survivors_df = df_new[df_new['survived'] == "Yes"]

# Finding the number of survivors
count_survivors_df = survivors_df.count()
print(count_survivors_df)

survivors_by_gender = survivors_df.groupby('sex')['survived'].count()
print("\nSurvivors by gender:\n", survivors_by_gender)
# Out:
# survived           281
# social_class       281
# sex                281
# age                281
# sibsp              281
# parch              281
# fare               281
# embarked_code      281
# ticket_class       281
# demographic        281
# adult_male         281
# embark_town        281
# alive              281
# alone              281
# fare parcentage    281
# dtype: int64
#
# Survivors by gender:
#  sex
# female    189
# male       92
# Name: survived, dtype: int64

# %%
# How many survived by age

# %% [markdown]
# **Exploring:** Comparing survivors by social class

# %%
# Using 'survivors df' from above to access survivors
survived_by_class = survivors_df.groupby('social_class')['survived'].count()
print("Survivors by social class: \n", survived_by_class)
# Out:
# Survivors by social class:
#  social_class
# Lower      83
# Middle     79
# Upper     119
# Name: survived, dtype: int64

# %% [markdown]
# **Exploring:** Comparing survivors by age group

# %%
# Using 'survivors df' from above to access survivors
age_group_1 = 0 # Ages 0-10
age_group_2 = 0 # Ages 10-21
age_group_3 = 0 # Ages 21-
age_group_4 = 0
survived_by_age = survivors_df.groupby('age')['survived'].count()
print("Survivors by age group: \n", survived_by_age)
# Out:
# Survivors by age group:
#  age
# 0      6
# 1      5
# 2      3
# 3      5
# 4      7
# 5      4
# 6      2
# 7      1
# 8      2
# 9      2
# 11     1
# 12     1
# 13     2
# 14     3
# 15     4
# 16     6
# 17     6
# 18     9
# 19     9
# 20     3
# 21     5
# 22    11
# 23     5
# 24    14
# 25     6
# 26     6
# 27    11
# 28     6
# 29     7
# 30    10
# 31     8
# 32     9
# 33     6
# 34     6
# 35    11
# 36    10
# 37     1
# 38     4
# 39     5
# 40     6
# 41     2
# 42     6
# 43     1
# 44     3
# 45     5
# 47     1
# 48     6
# 49     4
# 50     4
# 51     2
# 52     3
# 53     1
# 54     3
# 55     1
# 56     2
# 58     3
# 60     2
# 62     1
# 63     2
# 80     1
# Name: survived, dtype: int64
